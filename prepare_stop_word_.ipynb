# %% [markdown]
# <a href="https://colab.research.google.com/github/WebiksInc/data-explorer/blob/add-stop-word/prepare_stop_word_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests as req
# !pip install pyconll

ud_dev = 'https://raw.githubusercontent.com/UniversalDependencies/UD_Hebrew-IAHLTwiki/master/he_iahltwiki-ud-dev.conllu'
ud_test = 'https://github.com/UniversalDependencies/UD_Hebrew-IAHLTwiki/raw/master/he_iahltwiki-ud-test.conllu'
ud_train = 'https://github.com/UniversalDependencies/UD_Hebrew-IAHLTwiki/blob/master/he_iahltwiki-ud-train.conllu?raw=true'
# Out:
# Requirement already satisfied: pyconll in /usr/local/lib/python3.7/dist-packages (3.1.0)

# %%
def get_data(url:str,name:str):
  res = req.get(url)
  file = open(name + '.txt', 'w')
  file.write(res.text)
  file.close()
get_data(ud_dev,'ud_dev')
get_data(ud_test,'ud_test')
get_data(ud_train,'ud_train')

# %%
import pyconll
dev = pyconll.load_from_file('/content/ud_dev.txt')
train = pyconll.load_from_file('/content/ud_test.txt')
test = pyconll.load_from_file('/content/ud_train.txt')

# %%
def save_stopwords(dat):
  lst_words = []
  for sentence in dat:
      for token in sentence:
        if token.upos in ['DET','ADP','PRON','PUNCT','CCONJ','SCONJ']:
          lst_words.append(token.lemma)
  return lst_words 
set(save_stopwords(dev) + save_stopwords(train) + save_stopwords(test))
# Out:
# {'!',
#  '"',
#  "'",
#  '(',
#  ')',
#  ',',
#  '-',
#  '--',
#  '.',
#  '...',
#  '/',
#  ':',
#  ';',
#  '?',
#  None,
#  'The',
#  'You',
#  'Your',
#  '[',
#  ']',
#  'a',
#  'and',
#  'of',
#  'the',
#  'to',
#  'ְהַ',
#  'ַזֶּה',
#  '־',
#  'א',
#  'אִם',
#  'אֶל',
#  'אֶת',
#  'אבל',
#  'או',
#  'אוּלָם',
#  'אודות',
#  'אולם',
#  'אותה',
#  'אותו',
#  'אזר',
#  'אחר',
#  'אחרי',
#  'אי',
#  'איזה',
#  'אילו',
#  'אית',
#  'אך',
#  'אל',
#  'אלא',
#  'אלה',
#  'אליבא',
#  'אלמלא',
#  'אם',
#  'אנוכי',
#  'אף',
#  'אצל',
#  'אשר',
#  'את',
#  'ב',
#  'באם',
#  'באמצעות',
#  'באשר',
#  'בגדר',
#  'בגין',
#  'בגלל',
#  'בה',
#  'בהתבסס',
#  'בהתחשב',
#  'בזכות',
#  'בטרם',
#  'בידי',
#  'בין',
#  'בלא',
#  'בלי',
#  'בלעדי',
#  'במו',
#  'במקביל',
#  'במקום',
#  'במשך',
#  'בנוגע',
#  'בניגוד',
#  'בעבור',
#  'בעד',
#  'בעוד',
#  'בעקבות',
#  'בפני',
#  'בקרב',
#  'בקרבת',
#  'ברם',
#  'בשביל',
#  'בשל',
#  'בתוך',
#  'בתור',
#  'גב',
#  'ד',
#  'דוגמה',
#  'דם',
#  'דנן',
#  'דרך',
#  'דרכ',
#  'ה',
#  'הַ',
#  'הָ',
#  'האם',
#  'הגם',
#  'הוא',
#  'הודות',
#  'החל',
#  'היות',
#  'הלה',
#  'הללו',
#  'הן',
#  'הרבה',
#  'ו',
#  'וְ',
#  'וַ',
#  'זה',
#  'זהו',
#  'זולת',
#  'חרף',
#  'טרום',
#  'טרם',
#  'יד',
#  'יותר',
#  'יחד',
#  'יתר',
#  'כ',
#  'כִּי',
#  'כאילו',
#  'כאשר',
#  'כגון',
#  'כדי',
#  'כול',
#  'כולו',
#  'כי',
#  'כיוון',
#  'כך',
#  'ככל',
#  'כל',
#  'כלומר',
#  'כלל',
#  'כלפי',
#  'כלשהו',
#  'כמה',
#  'כמו',
#  'כמות',
#  'כן',
#  'כנגד',
#  'כעבור',
#  'כפי',
#  'כש',
#  'כשב-1948',
#  'ל',
#  'לא',
#  'לאור',
#  'לאורך',
#  'לאחר',
#  'לבד',
#  'לבין',
#  'לבל',
#  'לגבי',
#  'לה',
#  'לו',
#  'לולא',
#  'ליד',
#  'לידי',
#  'לכבוד',
#  'לכדי',
#  'ללא',
#  'למחרת',
#  'למן',
#  'למעט',
#  'למען',
#  'למרות',
#  'למשל',
#  'לנוכח',
#  'לעבר',
#  'לעומת',
#  'לפי',
#  'לפנות',
#  'לפני',
#  'לצד',
#  'לציד',
#  'לקראת',
#  'לרבות',
#  'לרגל',
#  'לשם',
#  'לתוך',
#  'מ',
#  'מאז',
#  'מאחורי',
#  'מאחר',
#  'מאשר',
#  'מאת',
#  'מבחינת',
#  'מבין',
#  'מבלי',
#  'מדי',
#  'מה',
#  'מול',
#  'מחמת',
#  'מחצית',
#  'מטעם',
#  'מי',
#  'מידי',
#  'מיטב',
#  'מירב',
#  'מישהו',
#  'מכיוון',
#  'מלבד',
#  'מן',
#  'מנה',
#  'מנת',
#  'מסביב',
#  'מספיק',
#  'מספר',
#  'מעבר',
#  'מעט',
#  'מעין',
#  'מעל',
#  'מפאת',
#  'מפני',
#  'מצד',
#  'מקרב',
#  'מרבית',
#  'מש',
#  'משהו',
#  'משום',
#  'משל',
#  'מתוך',
#  'מתוכן',
#  'מתחילת',
#  'מתחת',
#  "נ'",
#  'נאום',
#  'נגד',
#  'נוכח',
#  'נכון',
#  'סביב',
#  'ספר',
#  'ע"פ',
#  'ע"ש',
#  'עַד',
#  'עבור',
#  'עבר',
#  'עד',
#  'עוד',
#  'על',
#  'על-פי',
#  'עלי',
#  'עם',
#  'עניין',
#  'עצמו',
#  'עקב',
#  'ערב',
#  'ערך',
#  'עת',
#  'פה',
#  'פחות',
#  'פי',
#  'פר',
#  'פרט',
#  'קודם',
#  'קרוב',
#  'קרי',
#  'רוב',
#  'רובן',
#  'ש',
#  'שאר',
#  'שום',
#  'שורה',
#  'שכן',
#  'של',
#  'שמא',
#  'תוך',
#  'תחת',
#  'תחתי',
#  'תמורת',
#  '״',
#  '\u200f',
#  '–',
#  '—',
#  '“',
#  '”'}
